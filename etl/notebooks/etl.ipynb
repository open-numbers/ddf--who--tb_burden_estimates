# %%
import pandas as pd

# %%
# !ls ../source
# Out:
# LTBI_estimates_2018-07-17.csv
# MDR_RR_TB_burden_estimates_2018-07-17.csv
# TB_burden_countries_2018-07-17.csv
# TB_data_dictionary_2018-07-17.csv

# %%
tb = pd.read_csv('../source/TB_burden_countries_2018-07-17.csv')
mdr = pd.read_csv('../source/MDR_RR_TB_burden_estimates_2018-07-17.csv')
ltbi = pd.read_csv('../source/LTBI_estimates_2018-07-17.csv')
dic = pd.read_csv('../source/TB_data_dictionary_2018-07-17.csv')

# %%
tb.head()
# Out:
#        country iso2 iso3  iso_numeric g_whoregion  year  e_pop_num  \
# 0  Afghanistan   AF  AFG            4         EMR  2000   20093756
# 1  Afghanistan   AF  AFG            4         EMR  2001   20966463
# 2  Afghanistan   AF  AFG            4         EMR  2002   21979923
# 3  Afghanistan   AF  AFG            4         EMR  2003   23064851
# 4  Afghanistan   AF  AFG            4         EMR  2004   24118979
#
#    e_inc_100k  e_inc_100k_lo  e_inc_100k_hi    ...     e_mort_num  \
# 0       190.0          123.0          271.0    ...          14000
# 1       189.0          123.0          271.0    ...          13000
# 2       189.0          122.0          270.0    ...          12000
# 3       189.0          122.0          270.0    ...          13000
# 4       189.0          122.0          270.0    ...          12000
#
#    e_mort_num_lo  e_mort_num_hi  cfr  cfr_lo  cfr_hi  c_newinc_100k  c_cdr  \
# 0           7900          21000  NaN     NaN     NaN           35.0   19.0
# 1           7600          20000  NaN     NaN     NaN           48.0   26.0
# 2           7200          19000  NaN     NaN     NaN           63.0   33.0
# 3           7700          20000  NaN     NaN     NaN           60.0   32.0
# 4           7200          19000  NaN     NaN     NaN           76.0   40.0
#
#    c_cdr_lo  c_cdr_hi
# 0      13.0      29.0
# 1      18.0      39.0
# 2      23.0      51.0
# 3      22.0      49.0
# 4      28.0      62.0
#
# [5 rows x 71 columns]

# %%
mdr.head()
# Out:
#           country iso2 iso3  iso_numeric  year source_rr_new  \
# 0     Afghanistan   AF  AFG            4  2016         Model
# 1         Albania   AL  ALB            8  2016  Surveillance
# 2         Algeria   DZ  DZA           12  2016        Survey
# 3  American Samoa   AS  ASM           16  2016         Model
# 4         Andorra   AD  AND           20  2016  Surveillance
#
#   source_drs_coverage_new source_drs_year_new  e_rr_pct_new  e_rr_pct_new_lo  \
# 0                     NaN                2016           4.1             1.40
# 1                National                2012           2.3             0.64
# 2                National                2002           1.4             0.33
# 3                     NaN                2016           5.5             3.00
# 4                National                2016           0.0             0.00
#
#              ...             e_rr_pct_ret  e_rr_pct_ret_lo e_rr_pct_ret_hi  \
# 0            ...                     16.0            13.00            18.0
# 1            ...                      6.7             0.17            32.0
# 2            ...                      9.1             0.00            29.0
# 3            ...                     26.0            23.00            30.0
# 4            ...                      0.0             0.00             0.0
#
#   e_mdr_pct_rr_ret e_inc_rr_num  e_inc_rr_num_lo  e_inc_rr_num_hi  \
# 0             95.0         3300             1200             5400
# 1              0.0           12                2               23
# 2            100.0          460              140              780
# 3             75.0            0                0                0
# 4              NaN            0                0                0
#
#    e_rr_in_notified_pulm  e_rr_in_notified_pulm_lo  e_rr_in_notified_pulm_hi
# 0                 1600.0                     790.0                    2400.0
# 1                    7.0                       1.0                      14.0
# 2                  160.0                      24.0                     300.0
# 3                    NaN                       NaN                       NaN
# 4                    0.0                       0.0                       3.0
#
# [5 rows x 25 columns]

# %%
ltbi.head()
# Out:
#        country iso2 iso3  iso_numeric  year  \
# 0  Afghanistan   AF  AFG            4  2016
# 1      Albania   AL  ALB            8  2016
# 2      Algeria   DZ  DZA           12  2016
# 3       Angola   AO  AGO           24  2016
# 4    Argentina   AR  ARG           32  2016
#
#                                            source_hh  e_hh_size  \
# 0  Afghanistan living conditions survey (ALCS), 2...        7.4
# 1                                       Census, 2011        3.8
# 2  Dépenses de consommation des ménages algériens...        6.0
# 3                                     MIS, 2006-2007        5.7
# 4                                       Census, 2010        3.3
#
#    prevtx_data_available  newinc_con04_prevtx  ptsurvey_newinc  \
# 0                   60.0              15417.0              NaN
# 1                   60.0                  1.0              NaN
# 2                    0.0                  NaN              NaN
# 3                    0.0                  NaN              NaN
# 4                    0.0                  NaN              NaN
#
#    ptsurvey_newinc_con04_prevtx  e_prevtx_eligible  e_prevtx_eligible_lo  \
# 0                           NaN            20000.0               18000.0
# 1                           NaN               12.0                   7.5
# 2                           NaN             1200.0                 790.0
# 3                           NaN            28000.0               25000.0
# 4                           NaN              430.0                 280.0
#
#    e_prevtx_eligible_hi  e_prevtx_kids_pct  e_prevtx_kids_pct_lo  \
# 0               21000.0               79.0                  73.0
# 1                  16.0                8.6                   6.3
# 2                1700.0                NaN                   NaN
# 3               30000.0                NaN                   NaN
# 4                 580.0                NaN                   NaN
#
#    e_prevtx_kids_pct_hi
# 0                  87.0
# 1                  13.0
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
dic
# Out:
#                  variable_name                 dataset  \
# 0                          bmu    Community engagement
# 1           bmu_community_impl    Community engagement
# 2                 bmu_ref_data    Community engagement
# 3           bmu_rxsupport_data    Community engagement
# 4       bmu_rxsupport_data_coh    Community engagement
# 5     community_data_available    Community engagement
# 6                 notified_ref    Community engagement
# 7       notified_ref_community    Community engagement
# 8      rxsupport_community_coh    Community engagement
# 9     rxsupport_community_succ    Community engagement
# 10                     country  Country identification
# 11                 iso_numeric  Country identification
# 12                        iso2  Country identification
# 13                        iso3  Country identification
# 14                       c_cdr               Estimates
# 15                    c_cdr_hi               Estimates
# 16                    c_cdr_lo               Estimates
# 17               c_newinc_100k               Estimates
# 18                         cfr               Estimates
# 19                      cfr_hi               Estimates
# 20                      cfr_lo               Estimates
# 21                  e_inc_100k               Estimates
# 22               e_inc_100k_hi               Estimates
# 23               e_inc_100k_lo               Estimates
# 24                   e_inc_num               Estimates
# 25               e_inc_num_014               Estimates
# 26            e_inc_num_014_hi               Estimates
# 27            e_inc_num_014_lo               Estimates
# 28            e_inc_num_15plus               Estimates
# 29         e_inc_num_15plus_hi               Estimates
# ..                         ...                     ...
# 372                    ret_cur                Outcomes
# 373                    ret_def                Outcomes
# 374                   ret_died                Outcomes
# 375                   ret_fail                Outcomes
# 376               ret_nrel_coh                Outcomes
# 377              ret_nrel_died                Outcomes
# 378              ret_nrel_fail                Outcomes
# 379              ret_nrel_lost                Outcomes
# 380              ret_nrel_succ                Outcomes
# 381                  tbhiv_coh                Outcomes
# 382                 tbhiv_died                Outcomes
# 383                 tbhiv_fail                Outcomes
# 384                 tbhiv_lost                Outcomes
# 385                 tbhiv_succ                Outcomes
# 386                    xdr_coh                Outcomes
# 387                   xdr_died                Outcomes
# 388                   xdr_fail                Outcomes
# 389                   xdr_lost                Outcomes
# 390                   xdr_succ                Outcomes
# 391              caseb_err_nat                Strategy
# 392  digital_adherence_support                Strategy
# 393                   eol_care                Strategy
# 394           free_dx_followup                Strategy
# 395            hcw_tb_infected                Strategy
# 396                    hcw_tot                Strategy
# 397              mdr_tx_nonntp                Strategy
# 398                priv_new_dx                Strategy
# 399                 pub_new_dx                Strategy
# 400              universal_dst                Strategy
# 401           wrd_initial_test                Strategy
#
#                                              code_list  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                          0=No; 1=Yes
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 372                                                NaN
# 373                                                NaN
# 374                                                NaN
# 375                                                NaN
# 376                                                NaN
# 377                                                NaN
# 378                                                NaN
# 379                                                NaN
# 380                                                NaN
# 381                                                NaN
# 382                                                NaN
# 383                                                NaN
# 384                                                NaN
# 385                                                NaN
# 386                                                NaN
# 387                                                NaN
# 388                                                NaN
# 389                                                NaN
# 390                                                NaN
# 391  0=No; 42=Yes (all TB patients in the country);...
# 392  3=don't know; 210=Not used by any treatment ce...
# 393                                        0=No; 1=yes
# 394                                        0=No; 1=yes
# 395                                                NaN
# 396                                                NaN
# 397                                                NaN
# 398                                                NaN
# 399                                                NaN
# 400                                        0=No; 1=yes
# 401                                        0=No; 1=yes
#
#                                             definition
# 0    Number of TB Basic Management Units in the cou...
# 1    Number of TB Basic Management Units which impl...
# 2    Number of Basic Management Units with data on ...
# 3    Number of Basic Management Units with data on ...
# 4    Total number of patients who started TB treatm...
# 5    Are data available on community-based referral...
# 6    Total number of new and relapse TB cases notif...
# 7    Total number of new and relapse TB cases refer...
# 8    Total number of patients who started TB treatm...
# 9    Total number of patients who were cured or who...
# 10                           Country or territory name
# 11                  ISO numeric country/territory code
# 12              ISO 2-character country/territory code
# 13              ISO 3-character country/territory code
# 14            Case detection rate (all forms), percent
# 15   Case detection rate (all forms), percent, high...
# 16   Case detection rate (all forms), percent, low ...
# 17   Case notification rate, which is the total of ...
# 18                    Estimated TB case fatality ratio
# 19        Estimated TB case fatality ratio: high bound
# 20         Estimated TB case fatality ratio: low bound
# 21   Estimated incidence (all forms) per 100 000 po...
# 22   Estimated incidence (all forms) per 100 000 po...
# 23   Estimated incidence (all forms) per 100 000 po...
# 24      Estimated number of incident cases (all forms)
# 25   Estimated number of incident cases that are ag...
# 26   Estimated number of incident cases that are ma...
# 27   Estimated number of incident cases that are ag...
# 28   Estimated number of incident cases that are ag...
# 29   Estimated number of incident cases that are ag...
# ..                                                 ...
# 372  Outcomes for re-treatment cases: cured (not us...
# 373  Outcomes for re-treatment cases: defaulted (no...
# 374  Outcomes for re-treatment cases: died (not use...
# 375  Outcomes for re-treatment cases: failed (not u...
# 376  Outcomes for previously treated patients (excl...
# 377  Outcomes for previously treated patients (excl...
# 378  Outcomes for previously treated patients (excl...
# 379  Outcomes for previously treated patients (excl...
# 380  Outcomes for previously treated patients (excl...
# 381  Outcomes for HIV-positive TB cases, all types:...
# 382  Outcomes for HIV-positive TB cases, all types:...
# 383  Outcomes for HIV-positive TB cases, all types:...
# 384  Outcomes for HIV-positive TB cases, all types:...
# 385  Outcomes for HIV-positive TB cases, all types:...
# 386             Outcomes for XDR-TB cases: cohort size
# 387             Outcomes for XDR-TB cases: number died
# 388  Outcomes for XDR-TB cases: number whose treatm...
# 389       Outcomes for XDR-TB cases: lost to follow-up
# 390  Outcomes for XDR-TB cases: treatment success (...
# 391  Did the National Treatment Programme keep (or ...
# 392  Did any treatment centre use digital technolog...
# 393  Is there a component in the TB programme that ...
# 394  Does national policy indicate that TB diagnost...
# 395           Number of health-care workers who had TB
# 396  Total number of health-care workers who were w...
# 397  Number of patients started on MDR-TB treatment...
# 398  Number of new cases of TB diagnosed according ...
# 399  Number of new cases of TB diagnosed according ...
# 400  Does national policy and the diagnostic algori...
# 401  Does national policy and the diagnostic algori...
#
# [402 rows x 4 columns]

# %%
# datapoints

# %%
tb.columns
# Out:
# Index(['country', 'iso2', 'iso3', 'iso_numeric', 'g_whoregion', 'year',
#        'e_pop_num', 'e_inc_100k', 'e_inc_100k_lo', 'e_inc_100k_hi',
#        'e_inc_num', 'e_inc_num_lo', 'e_inc_num_hi', 'e_inc_num_f014',
#        'e_inc_num_f014_lo', 'e_inc_num_f014_hi', 'e_inc_num_f15plus',
#        'e_inc_num_f15plus_lo', 'e_inc_num_f15plus_hi', 'e_inc_num_f',
#        'e_inc_num_f_lo', 'e_inc_num_f_hi', 'e_inc_num_m014',
#        'e_inc_num_m014_lo', 'e_inc_num_m014_hi', 'e_inc_num_m15plus',
#        'e_inc_num_m15plus_lo', 'e_inc_num_m15plus_hi', 'e_inc_num_m',
#        'e_inc_num_m_lo', 'e_inc_num_m_hi', 'e_inc_num_014', 'e_inc_num_014_lo',
#        'e_inc_num_014_hi', 'e_inc_num_15plus', 'e_inc_num_15plus_lo',
#        'e_inc_num_15plus_hi', 'e_tbhiv_prct', 'e_tbhiv_prct_lo',
#        'e_tbhiv_prct_hi', 'e_inc_tbhiv_100k', 'e_inc_tbhiv_100k_lo',
#        'e_inc_tbhiv_100k_hi', 'e_inc_tbhiv_num', 'e_inc_tbhiv_num_lo',
#        'e_inc_tbhiv_num_hi', 'e_mort_exc_tbhiv_100k',
#        'e_mort_exc_tbhiv_100k_lo', 'e_mort_exc_tbhiv_100k_hi',
#        'e_mort_exc_tbhiv_num', 'e_mort_exc_tbhiv_num_lo',
#        'e_mort_exc_tbhiv_num_hi', 'e_mort_tbhiv_100k', 'e_mort_tbhiv_100k_lo',
#        'e_mort_tbhiv_100k_hi', 'e_mort_tbhiv_num', 'e_mort_tbhiv_num_lo',
#        'e_mort_tbhiv_num_hi', 'e_mort_100k', 'e_mort_100k_lo',
#        'e_mort_100k_hi', 'e_mort_num', 'e_mort_num_lo', 'e_mort_num_hi', 'cfr',
#        'cfr_lo', 'cfr_hi', 'c_newinc_100k', 'c_cdr', 'c_cdr_lo', 'c_cdr_hi'],
#       dtype='object')

# %%
cols = list(tb.columns)
for c in ['country', 'iso2', 'iso_numeric', 'g_whoregion']:
    cols.remove(c)

# %%
tb_ = tb[cols].copy()

# %%
tb_['iso3'] = tb_['iso3'].str.lower()

# %%
tb_ = tb_.set_index(['iso3', 'year'])

# %%
tb_.head()
# Out:
#            e_pop_num  e_inc_100k  e_inc_100k_lo  e_inc_100k_hi  e_inc_num  \
# iso3 year
# afg  2000   20093756       190.0          123.0          271.0      38000
#      2001   20966463       189.0          123.0          271.0      40000
#      2002   21979923       189.0          122.0          270.0      42000
#      2003   23064851       189.0          122.0          270.0      44000
#      2004   24118979       189.0          122.0          270.0      46000
#
#            e_inc_num_lo  e_inc_num_hi  e_inc_num_f014  e_inc_num_f014_lo  \
# iso3 year
# afg  2000         25000         54000             NaN                NaN
#      2001         26000         57000             NaN                NaN
#      2002         27000         59000             NaN                NaN
#      2003         28000         62000             NaN                NaN
#      2004         29000         65000             NaN                NaN
#
#            e_inc_num_f014_hi    ...     e_mort_num  e_mort_num_lo  \
# iso3 year                       ...
# afg  2000                NaN    ...          14000           7900
#      2001                NaN    ...          13000           7600
#      2002                NaN    ...          12000           7200
#      2003                NaN    ...          13000           7700
#      2004                NaN    ...          12000           7200
#
#            e_mort_num_hi  cfr  cfr_lo  cfr_hi  c_newinc_100k  c_cdr  c_cdr_lo  \
# iso3 year
# afg  2000          21000  NaN     NaN     NaN           35.0   19.0      13.0
#      2001          20000  NaN     NaN     NaN           48.0   26.0      18.0
#      2002          19000  NaN     NaN     NaN           63.0   33.0      23.0
#      2003          20000  NaN     NaN     NaN           60.0   32.0      22.0
#      2004          19000  NaN     NaN     NaN           76.0   40.0      28.0
#
#            c_cdr_hi
# iso3 year
# afg  2000      29.0
#      2001      39.0
#      2002      51.0
#      2003      49.0
#      2004      62.0
#
# [5 rows x 65 columns]

# %%
for c in tb_:
    df = tb_[[c]].dropna().reset_index()
    df.columns = ['country', 'year', c]
    df.to_csv(f'../../ddf--datapoints--{c}--by--country--year.csv', index=False)

# %%
mdr.columns
# Out:
# Index(['country', 'iso2', 'iso3', 'iso_numeric', 'year', 'source_rr_new',
#        'source_drs_coverage_new', 'source_drs_year_new', 'e_rr_pct_new',
#        'e_rr_pct_new_lo', 'e_rr_pct_new_hi', 'e_mdr_pct_rr_new',
#        'source_rr_ret', 'source_drs_coverage_ret', 'source_drs_year_ret',
#        'e_rr_pct_ret', 'e_rr_pct_ret_lo', 'e_rr_pct_ret_hi',
#        'e_mdr_pct_rr_ret', 'e_inc_rr_num', 'e_inc_rr_num_lo',
#        'e_inc_rr_num_hi', 'e_rr_in_notified_pulm', 'e_rr_in_notified_pulm_lo',
#        'e_rr_in_notified_pulm_hi'],
#       dtype='object')

# %%
cols = list(mdr.columns)
for c in ['country', 'iso2', 'iso_numeric']:
    cols.remove(c)

# %%
cols
# Out:
# ['iso3',
#  'year',
#  'source_rr_new',
#  'source_drs_coverage_new',
#  'source_drs_year_new',
#  'e_rr_pct_new',
#  'e_rr_pct_new_lo',
#  'e_rr_pct_new_hi',
#  'e_mdr_pct_rr_new',
#  'source_rr_ret',
#  'source_drs_coverage_ret',
#  'source_drs_year_ret',
#  'e_rr_pct_ret',
#  'e_rr_pct_ret_lo',
#  'e_rr_pct_ret_hi',
#  'e_mdr_pct_rr_ret',
#  'e_inc_rr_num',
#  'e_inc_rr_num_lo',
#  'e_inc_rr_num_hi',
#  'e_rr_in_notified_pulm',
#  'e_rr_in_notified_pulm_lo',
#  'e_rr_in_notified_pulm_hi']

# %%
mdr_ = mdr[cols].copy()
mdr_['iso3'] = mdr_['iso3'].str.lower()
mdr_ = mdr_.set_index(['iso3', 'year'])

# %%
mdr_.head()
# Out:
#           source_rr_new source_drs_coverage_new source_drs_year_new  \
# iso3 year
# afg  2016         Model                     NaN                2016
# alb  2016  Surveillance                National                2012
# dza  2016        Survey                National                2002
# asm  2016         Model                     NaN                2016
# and  2016  Surveillance                National                2016
#
#            e_rr_pct_new  e_rr_pct_new_lo  e_rr_pct_new_hi  e_mdr_pct_rr_new  \
# iso3 year
# afg  2016           4.1             1.40              6.9              85.0
# alb  2016           2.3             0.64              5.8              25.0
# dza  2016           1.4             0.33              2.5             100.0
# asm  2016           5.5             3.00              8.0              76.0
# and  2016           0.0             0.00             84.0               NaN
#
#           source_rr_ret source_drs_coverage_ret source_drs_year_ret  \
# iso3 year
# afg  2016         Model                     NaN                2016
# alb  2016  Surveillance                National                2012
# dza  2016        Survey                National                2002
# asm  2016         Model                     NaN                2016
# and  2016  Surveillance                National                2016
#
#            e_rr_pct_ret  e_rr_pct_ret_lo  e_rr_pct_ret_hi  e_mdr_pct_rr_ret  \
# iso3 year
# afg  2016          16.0            13.00             18.0              95.0
# alb  2016           6.7             0.17             32.0               0.0
# dza  2016           9.1             0.00             29.0             100.0
# asm  2016          26.0            23.00             30.0              75.0
# and  2016           0.0             0.00              0.0               NaN
#
#            e_inc_rr_num  e_inc_rr_num_lo  e_inc_rr_num_hi  \
# iso3 year
# afg  2016          3300             1200             5400
# alb  2016            12                2               23
# dza  2016           460              140              780
# asm  2016             0                0                0
# and  2016             0                0                0
#
#            e_rr_in_notified_pulm  e_rr_in_notified_pulm_lo  \
# iso3 year
# afg  2016                 1600.0                     790.0
# alb  2016                    7.0                       1.0
# dza  2016                  160.0                      24.0
# asm  2016                    NaN                       NaN
# and  2016                    0.0                       0.0
#
#            e_rr_in_notified_pulm_hi
# iso3 year
# afg  2016                    2400.0
# alb  2016                      14.0
# dza  2016                     300.0
# asm  2016                       NaN
# and  2016                       3.0

# %%
for c in mdr_:
    df = mdr_[[c]].dropna().reset_index()
    df.columns = ['country', 'year', c]
    df.to_csv(f'../../ddf--datapoints--{c}--by--country--year.csv', index=False)

# %%
ltbi.columns
# Out:
# Index(['country', 'iso2', 'iso3', 'iso_numeric', 'year', 'source_hh',
#        'e_hh_size', 'prevtx_data_available', 'newinc_con04_prevtx',
#        'ptsurvey_newinc', 'ptsurvey_newinc_con04_prevtx', 'e_prevtx_eligible',
#        'e_prevtx_eligible_lo', 'e_prevtx_eligible_hi', 'e_prevtx_kids_pct',
#        'e_prevtx_kids_pct_lo', 'e_prevtx_kids_pct_hi'],
#       dtype='object')

# %%
cols = list(ltbi.columns)
for c in ['country', 'iso2', 'iso_numeric']:
    cols.remove(c)

# %%
ltbi_ = ltbi[cols].copy()
ltbi_['iso3'] = ltbi_['iso3'].str.lower()
ltbi_ = ltbi_.set_index(['iso3', 'year'])

# %%
ltbi_.head()
# Out:
#                                                    source_hh  e_hh_size  \
# iso3 year
# afg  2016  Afghanistan living conditions survey (ALCS), 2...        7.4
# alb  2016                                       Census, 2011        3.8
# dza  2016  Dépenses de consommation des ménages algériens...        6.0
# ago  2016                                     MIS, 2006-2007        5.7
# arg  2016                                       Census, 2010        3.3
#
#            prevtx_data_available  newinc_con04_prevtx  ptsurvey_newinc  \
# iso3 year
# afg  2016                   60.0              15417.0              NaN
# alb  2016                   60.0                  1.0              NaN
# dza  2016                    0.0                  NaN              NaN
# ago  2016                    0.0                  NaN              NaN
# arg  2016                    0.0                  NaN              NaN
#
#            ptsurvey_newinc_con04_prevtx  e_prevtx_eligible  \
# iso3 year
# afg  2016                           NaN            20000.0
# alb  2016                           NaN               12.0
# dza  2016                           NaN             1200.0
# ago  2016                           NaN            28000.0
# arg  2016                           NaN              430.0
#
#            e_prevtx_eligible_lo  e_prevtx_eligible_hi  e_prevtx_kids_pct  \
# iso3 year
# afg  2016               18000.0               21000.0               79.0
# alb  2016                   7.5                  16.0                8.6
# dza  2016                 790.0                1700.0                NaN
# ago  2016               25000.0               30000.0                NaN
# arg  2016                 280.0                 580.0                NaN
#
#            e_prevtx_kids_pct_lo  e_prevtx_kids_pct_hi
# iso3 year
# afg  2016                  73.0                  87.0
# alb  2016                   6.3                  13.0
# dza  2016                   NaN                   NaN
# ago  2016                   NaN                   NaN
# arg  2016                   NaN                   NaN

# %%
for c in ltbi_:
    df = ltbi_[[c]].dropna().reset_index()
    df.columns = ['country', 'year', c]
    df.to_csv(f'../../ddf--datapoints--{c}--by--country--year.csv', index=False)

# %%
# !open ../../

# %%
# concepts

# %%
dic.columns
# Out:
# Index(['variable_name', 'dataset', 'code_list', 'definition'], dtype='object')

# %%
cdf = dic[['variable_name', 'definition']].copy()

# %%
cdf.columns = ['concept', 'name']

# %%
cdf['concept_type'] = 'measure'

# %%
cdf.loc[cdf.concept.str.contains('source'), 'concept_type'] = 'string'
cdf.loc[cdf.concept.str.startswith('iso'), 'concept_type'] = 'string'
cdf.loc[cdf.concept=='country', 'concept_type'] = 'entity_domain'

# %%
cdf_2 = pd.DataFrame([], columns=['concept', 'name', 'concept_type'])
cdf_2['concept'] = ['name', 'year']
cdf_2['name'] = ['Name', 'Year']
cdf_2['concept_type'] = ['string', 'time']

# %%
cdf_ = pd.concat([cdf, cdf_2]).sort_values(by=['concept_type', 'concept'])

# %%
cdf_.to_csv('../../ddf--concepts.csv', index=False)

# %%
# entity

# %%
country1 = tb[['country', 'iso2', 'iso3', 'iso_numeric']]

# %%
country2 = ltbi[['country', 'iso2', 'iso3', 'iso_numeric']]

# %%
country3 = mdr[['country', 'iso2', 'iso3', 'iso_numeric']]

# %%
country = pd.concat([country1, country2, country3], ignore_index=True)

# %%
country = country.drop_duplicates()

# %%
country.columns
# Out:
# Index(['country', 'iso2', 'iso3', 'iso_numeric'], dtype='object')

# %%
country = country.rename(columns={'country': 'name'})

# %%
country['country'] = country['iso3'].str.lower()

# %%
country = country[['country', 'name', 'iso3', 'iso2', 'iso_numeric']]

# %%
country.sort_values(by=['country']).to_csv('../../ddf--entities--country.csv', index=False)
